# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

ventricle = pd.read_csv("Ventricle_processed.csv", index_col=0)
article = pd.read_csv("Atrial_processed.csv", index_col=0)

# %%
ventricle_data = ventricle.iloc[:,2:]
ventricle_data.head()
# Out:
#    0  0.00666666666666667  0.0133333333333333      0.02  0.0266666666666667  \
# ﻿
# 1  0             5.092451            0.351825  7.265679            1.088919
# 2  0            12.231399            0.000000  0.000000            6.130987
# 3  0             1.157857            5.272938  2.424059            0.143458
# 4  0             4.105790            0.110073  2.318635            6.755368
# 5  0             1.149653            1.322130  2.140996            1.513913
#
#    0.0333333333333333      0.04  0.0466666666666667  0.0533333333333333  \
# ﻿
# 1            0.291461  2.434897            0.291461            4.048291
# 2            3.577025  0.000000            2.194904            2.710547
# 3            2.608506  1.420159            1.570159            1.958515
# 4            4.479086  2.099212            0.466277            4.090569
# 5            1.199684  0.860783            1.045139            1.931282
#
#         0.06        ...         29.9333333333333     29.94  29.9466666666667  \
# ﻿                   ...
# 1   4.439966        ...                 2.238202  1.226209          6.041713
# 2  11.321776        ...                 2.069375  1.293359          0.517344
# 3   1.420159        ...                 0.000000  2.125919          1.881688
# 4   5.610008        ...                 0.822481  0.971773          0.660439
# 5   1.372162        ...                 1.886332  2.306046          2.723130
#
#    29.9533333333333     29.96  29.9666666666667  29.9733333333333     29.98  \
# ﻿
# 1          2.436813  1.165845          3.183951          2.573145  1.578034
# 2          4.520546  2.689760          0.517344          4.368024  5.905072
# 3          5.817603  6.477642          4.161932          0.818062  0.101440
# 4          0.770512  1.858733          1.540001          0.458155  2.491441
# 5          2.278302  4.108142          2.786012          3.365353  3.941718
#
#    29.9866666666667  29.9933333333333
# ﻿
# 1          2.109034          1.734121
# 2          0.517344          2.477169
# 3          0.650658          1.916497
# 4          0.440293          7.826697
# 5          4.933291          2.071375
#
# [5 rows x 4500 columns]

# %%
# convert it to numpy array (number of cells * 4500)
vnp = ventricle_data.values
vfft = np.fft.fft(vnp, axis=1)

# %%
vpwr = vfft.real ** 2 + vfft.imag ** 2
vpwr = vpwr[:,:int(vpwr.shape[1] / 2)]

# %%
# Out:
# (100, 2250)
